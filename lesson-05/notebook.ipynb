# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import py_vncorenlp

# %%
df = pd.read_json('./data/wordSegmentedDataset/train.json')
df
# Out:
#                                                 sentence sentiment  \
# 0                              slide giáo trình đầy đủ .  positive
# 1         nhiệt tình giảng dạy , gần gũi với sinh viên .  positive
# 2                   đi học đầy đủ full điểm chuyên cần .  negative
# 3      chưa áp dụng công nghệ thông tin và các thiết ...  negative
# 4      thầy giảng bài hay , có nhiều bài tập ví dụ ng...  positive
# ...                                                  ...       ...
# 11421  chỉ vì môn game mà em học hai lần mà không qua...  negative
# 11422                               em cảm ơn cô nhiều .  positive
# 11423                           giao bài tập quá nhiều .  negative
# 11424               giáo viên dạy dễ hiểu , nhiệt tình .  positive
# 11425  gói gọn doubledot hay , tận tình , phù hợp với...  positive
#
#                   topic                                 tokenized_sentence
# 0      training_program                          slide giáo_trình đầy_đủ .
# ...

# %%
df2 = pd.read_json(r'C:\Users\VICTUS\Documents\developer\uit-practicalLesson-sML\lesson-05\data\originalDataset\UIT_VSFC_dev.json')
df2
# Out:
#                                                sentence sentiment  \
# 0                              giáo trình chưa cụ thể .  negative
# 1                                      giảng buồn ngủ .  negative
# 2                        giáo viên vui tính , tận tâm .  positive
# 3     giảng viên nên giao bài tập nhiều hơn , chia n...  negative
# 4     giảng viên cần giảng bài chi tiết hơn , đi sâu...  negative
# ...                                                 ...       ...
# 1578                              hướng dẫn lab mơ hồ .  negative
# 1579  thầy cho chúng em những bài tập mang tính thực...  positive
# 1580  thầy không dạy nhiều chủ yếu cho sinh viên tự ...  negative
# 1581  em muốn đổi tên môn học vì tên môn là lập trìn...  negative
# 1582  thầy vừa dạy vừa chat hoặc gọi điện thoại thườ...  negative
#
#                  topic
# 0     training_program
# 1             lecturer
# 2             lecturer
# 3             lecturer
# 4             lecturer
# ...                ...
# ...
